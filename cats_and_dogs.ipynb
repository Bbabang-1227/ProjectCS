# %% [markdown]
# <a href="https://colab.research.google.com/github/Bbabang-1227/ProjectCS/blob/main/cats_and_dogs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --no-check-certificate \
https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
-O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2021-06-30 08:16:59--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.15.80, 172.217.13.240, 172.217.9.208, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.15.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M   216MB/s    in 0.3s
#
# 2021-06-30 08:16:59 (216 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %% [markdown]
# # 새 섹션

# %%
import os
import zipfile

local_zip = '/tmp/cats_and_dogs_filtered.zip'

zip_ref = zipfile.ZipFile(local_zip, 'r')

zip_ref.extractall('/tmp')
zip_ref.close()

# %% [markdown]
# # 새 섹션

# %%
base_dir = '/tmp/cats_and_dogs_filtered'

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# 훈련에 사용되는 고양이/개 이미지 경로
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')
print(train_cats_dir)
print(train_dogs_dir)

# 테스트에 사용되는 고양이/개 이미지 경로
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')
print(validation_cats_dir)
print(validation_dogs_dir)
# Out:
# /tmp/cats_and_dogs_filtered/train/cats
# /tmp/cats_and_dogs_filtered/train/dogs
# /tmp/cats_and_dogs_filtered/validation/cats
# /tmp/cats_and_dogs_filtered/validation/dogs

# %% [markdown]
# # 새 섹션

# %%
train_cat_fnames = os.listdir( train_cats_dir )
train_dog_fnames = os.listdir( train_dogs_dir )

print(train_cat_fnames[:5])
print(train_dog_fnames[:5])
# Out:
# ['cat.780.jpg', 'cat.273.jpg', 'cat.835.jpg', 'cat.223.jpg', 'cat.661.jpg']
# ['dog.292.jpg', 'dog.382.jpg', 'dog.552.jpg', 'dog.664.jpg', 'dog.291.jpg']

# %% [markdown]
# # 새 섹션

# %%
print('Total training cat images :', len(os.listdir(train_cats_dir)))
print('Total training dog images :', len(os.listdir(train_dogs_dir)))

print('Total validation cat images :', len(os.listdir(validation_cats_dir)))
print('Total validation dog images :', len(os.listdir(validation_dogs_dir)))
# Out:
# Total training cat images : 1000
# Total training dog images : 1000
# Total validation cat images : 500
# Total validation dog images : 500

# %% [markdown]
# # 새 섹션

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

nrows, ncols = 4, 4
pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols*3, nrows*3)

pic_index+=8

next_cat_pix = [os.path.join(train_cats_dir, fname)
                for fname in train_cat_fnames[ pic_index-8:pic_index]]

next_dog_pix = [os.path.join(train_dogs_dir, fname)
                for fname in train_dog_fnames[ pic_index-8:pic_index]]

for i, img_path in enumerate(next_cat_pix+next_dog_pix):
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off')

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
import tensorflow as tf


model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 18496)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               9470464
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 새 섹션

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(optimizer=RMSprop(lr=0.001),
            loss='binary_crossentropy',
            metrics = ['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )

train_generator = train_datagen.flow_from_directory(train_dir,
                                                  batch_size=20,
                                                  class_mode='binary',
                                                  target_size=(150, 150))
validation_generator =  test_datagen.flow_from_directory(validation_dir,
                                                       batch_size=20,
                                                       class_mode  = 'binary',
                                                       target_size = (150, 150))
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
history = model.fit(train_generator,
                    validation_data=validation_generator,
                    steps_per_epoch=100,
                    epochs=100,
                    validation_steps=50,
                    verbose=2)
# Out:
# Epoch 1/100
# 100/100 - 58s - loss: 1.0154 - accuracy: 0.5430 - val_loss: 0.6573 - val_accuracy: 0.6710
# Epoch 2/100
# 100/100 - 56s - loss: 0.6571 - accuracy: 0.6495 - val_loss: 0.6185 - val_accuracy: 0.6380
# Epoch 3/100
# 100/100 - 56s - loss: 0.5819 - accuracy: 0.6875 - val_loss: 0.5803 - val_accuracy: 0.6920
# Epoch 4/100
# 100/100 - 56s - loss: 0.4964 - accuracy: 0.7570 - val_loss: 0.5808 - val_accuracy: 0.7120
# Epoch 5/100
# 100/100 - 56s - loss: 0.4236 - accuracy: 0.8045 - val_loss: 0.5968 - val_accuracy: 0.7160
# Epoch 6/100
# 100/100 - 56s - loss: 0.3383 - accuracy: 0.8505 - val_loss: 0.7326 - val_accuracy: 0.6600
# Epoch 7/100
# 100/100 - 56s - loss: 0.2530 - accuracy: 0.8900 - val_loss: 0.7999 - val_accuracy: 0.7090
# Epoch 8/100
# 100/100 - 56s - loss: 0.1785 - accuracy: 0.9280 - val_loss: 0.9110 - val_accuracy: 0.7330
# Epoch 9/100
# 100/100 - 56s - loss: 0.1338 - accuracy: 0.9510 - val_loss: 0.9822 - val_accuracy: 0.7180
# Epoch 10/100
# 100/100 - 56s - loss: 0.1264 - accuracy: 0.9595 - val_loss: 1.0167 - val_accuracy: 0.7220
# Epoch 11/100
# 100/100 - 56s - loss: 0.0938 - accuracy: 0.9745 - val_loss: 1.2187 - val_accuracy: 0.7260
# Epoch 12/100
# 100/100 - 56s - loss: 0.0659 - accuracy: 0.9830 - val_loss: 1.4431 - val_accuracy: 0.7070
# Epoch 13/100
# 100/100 - 57s - loss: 0.0956 - accuracy: 0.9810 - val_loss: 1.5003 - val_accuracy: 0.7200
# Epoch 14/100
# 100/100 - 57s - loss: 0.0460 - accuracy: 0.9880 - val_loss: 1.8258 - val_accuracy: 0.7190
# Epoch 15/100
# 100/100 - 57s - loss: 0.0314 - accuracy: 0.9865 - val_loss: 2.0798 - val_accuracy: 0.7230
# Epoch 16/100
# 100/100 - 56s - loss: 0.0609 - accuracy: 0.9905 - val_loss: 1.9714 - val_accuracy: 0.7290
# Epoch 17/100
# 100/100 - 56s - loss: 0.0489 - accuracy: 0.9830 - val_loss: 1.9368 - val_accuracy: 0.7310
# Epoch 18/100
# 100/100 - 56s - loss: 0.0276 - accuracy: 0.9925 - val_loss: 2.0819 - val_accuracy: 0.7220
# Epoch 19/100
# 100/100 - 57s - loss: 0.0505 - accuracy: 0.9855 - val_loss: 2.3211 - val_accuracy: 0.7060
# Epoch 20/100
# 100/100 - 56s - loss: 0.0183 - accuracy: 0.9945 - val_loss: 2.2324 - val_accuracy: 0.7230
# Epoch 21/100
# 100/100 - 56s - loss: 0.0277 - accuracy: 0.9940 - val_loss: 2.5431 - val_accuracy: 0.7310
# Epoch 22/100
# 100/100 - 56s - loss: 0.0806 - accuracy: 0.9925 - val_loss: 2.1547 - val_accuracy: 0.7280
# Epoch 23/100
# 100/100 - 56s - loss: 0.0324 - accuracy: 0.9925 - val_loss: 2.0295 - val_accuracy: 0.7210
# Epoch 24/100
# 100/100 - 56s - loss: 0.0411 - accuracy: 0.9935 - val_loss: 2.3257 - val_accuracy: 0.7170
# Epoch 25/100
# 100/100 - 56s - loss: 0.0128 - accuracy: 0.9955 - val_loss: 2.7289 - val_accuracy: 0.7040
# Epoch 26/100
# 100/100 - 56s - loss: 0.0270 - accuracy: 0.9920 - val_loss: 2.7988 - val_accuracy: 0.7130
# Epoch 27/100
# 100/100 - 56s - loss: 0.0198 - accuracy: 0.9935 - val_loss: 2.9566 - val_accuracy: 0.7110
# Epoch 28/100
# 100/100 - 56s - loss: 0.0159 - accuracy: 0.9960 - val_loss: 3.1191 - val_accuracy: 0.7160
# Epoch 29/100
# 100/100 - 57s - loss: 0.0076 - accuracy: 0.9965 - val_loss: 2.8162 - val_accuracy: 0.7110
# Epoch 30/100
# 100/100 - 57s - loss: 3.3772e-05 - accuracy: 1.0000 - val_loss: 3.4805 - val_accuracy: 0.7350
# Epoch 31/100
# 100/100 - 56s - loss: 0.0450 - accuracy: 0.9920 - val_loss: 3.7892 - val_accuracy: 0.7090
# Epoch 32/100
# 100/100 - 57s - loss: 0.0178 - accuracy: 0.9950 - val_loss: 3.3139 - val_accuracy: 0.7130
# Epoch 33/100
# 100/100 - 57s - loss: 0.0429 - accuracy: 0.9935 - val_loss: 3.1595 - val_accuracy: 0.6950
# Epoch 34/100
# 100/100 - 56s - loss: 8.7571e-04 - accuracy: 0.9995 - val_loss: 4.0988 - val_accuracy: 0.7210
# Epoch 35/100
# 100/100 - 57s - loss: 0.0399 - accuracy: 0.9960 - val_loss: 3.2906 - val_accuracy: 0.7100
# Epoch 36/100
# 100/100 - 57s - loss: 0.0094 - accuracy: 0.9980 - val_loss: 3.8233 - val_accuracy: 0.7070
# Epoch 37/100
# 100/100 - 57s - loss: 0.0093 - accuracy: 0.9985 - val_loss: 3.5400 - val_accuracy: 0.6900
# Epoch 38/100
# 100/100 - 57s - loss: 0.0065 - accuracy: 0.9970 - val_loss: 4.3805 - val_accuracy: 0.6980
# Epoch 39/100
# 100/100 - 57s - loss: 0.0243 - accuracy: 0.9965 - val_loss: 3.8569 - val_accuracy: 0.6800
# Epoch 40/100
# 100/100 - 57s - loss: 0.0099 - accuracy: 0.9955 - val_loss: 3.8738 - val_accuracy: 0.7060
# Epoch 41/100
# 100/100 - 57s - loss: 0.0328 - accuracy: 0.9965 - val_loss: 5.2042 - val_accuracy: 0.6800
# Epoch 42/100
# 100/100 - 57s - loss: 0.0578 - accuracy: 0.9940 - val_loss: 3.5037 - val_accuracy: 0.6960
# Epoch 43/100
# 100/100 - 57s - loss: 1.5953e-05 - accuracy: 1.0000 - val_loss: 4.4360 - val_accuracy: 0.7120
# Epoch 44/100
# 100/100 - 57s - loss: 0.0062 - accuracy: 0.9990 - val_loss: 5.1288 - val_accuracy: 0.7000
# Epoch 45/100
# 100/100 - 57s - loss: 0.0176 - accuracy: 0.9960 - val_loss: 5.4168 - val_accuracy: 0.6620
# Epoch 46/100
# 100/100 - 57s - loss: 0.0023 - accuracy: 0.9990 - val_loss: 5.0127 - val_accuracy: 0.7160
# Epoch 47/100
# 100/100 - 57s - loss: 1.8834e-07 - accuracy: 1.0000 - val_loss: 5.3036 - val_accuracy: 0.7200
# Epoch 48/100
# 100/100 - 57s - loss: 0.0552 - accuracy: 0.9945 - val_loss: 5.3194 - val_accuracy: 0.7140
# Epoch 49/100
# 100/100 - 57s - loss: 0.0245 - accuracy: 0.9975 - val_loss: 5.5777 - val_accuracy: 0.6450
# Epoch 50/100
# 100/100 - 57s - loss: 0.0671 - accuracy: 0.9930 - val_loss: 5.0556 - val_accuracy: 0.6920
# Epoch 51/100
# 100/100 - 56s - loss: 0.0018 - accuracy: 0.9995 - val_loss: 4.9316 - val_accuracy: 0.6960
# Epoch 52/100
# 100/100 - 56s - loss: 8.1798e-07 - accuracy: 1.0000 - val_loss: 5.5248 - val_accuracy: 0.7110
# Epoch 53/100
# 100/100 - 56s - loss: 0.0424 - accuracy: 0.9945 - val_loss: 6.0548 - val_accuracy: 0.7080
# Epoch 54/100
# 100/100 - 56s - loss: 3.3045e-04 - accuracy: 1.0000 - val_loss: 5.4326 - val_accuracy: 0.7180
# Epoch 55/100
# 100/100 - 56s - loss: 0.0383 - accuracy: 0.9950 - val_loss: 4.9224 - val_accuracy: 0.7210
# Epoch 56/100
# 100/100 - 56s - loss: 9.3533e-07 - accuracy: 1.0000 - val_loss: 5.4994 - val_accuracy: 0.7290
# Epoch 57/100
# 100/100 - 57s - loss: 0.0599 - accuracy: 0.9950 - val_loss: 6.5906 - val_accuracy: 0.7130
# Epoch 58/100
# 100/100 - 57s - loss: 0.0269 - accuracy: 0.9955 - val_loss: 3.9377 - val_accuracy: 0.7010
# Epoch 59/100
# 100/100 - 57s - loss: 0.0251 - accuracy: 0.9955 - val_loss: 5.4395 - val_accuracy: 0.7120
# Epoch 60/100
# 100/100 - 57s - loss: 3.5564e-06 - accuracy: 1.0000 - val_loss: 5.5373 - val_accuracy: 0.7170
# Epoch 61/100
# 100/100 - 57s - loss: 0.0472 - accuracy: 0.9965 - val_loss: 4.2320 - val_accuracy: 0.6940
# Epoch 62/100
# 100/100 - 57s - loss: 0.0022 - accuracy: 0.9995 - val_loss: 4.9396 - val_accuracy: 0.7080
# Epoch 63/100
# 100/100 - 57s - loss: 2.2391e-07 - accuracy: 1.0000 - val_loss: 5.3894 - val_accuracy: 0.7050
# Epoch 64/100
# 100/100 - 57s - loss: 0.0113 - accuracy: 0.9980 - val_loss: 5.3712 - val_accuracy: 0.7110
# Epoch 65/100
# 100/100 - 57s - loss: 0.0094 - accuracy: 0.9980 - val_loss: 5.0544 - val_accuracy: 0.7110
# Epoch 66/100
# 100/100 - 57s - loss: 3.8739e-05 - accuracy: 1.0000 - val_loss: 5.0427 - val_accuracy: 0.7080
# Epoch 67/100
# 100/100 - 57s - loss: 2.8352e-07 - accuracy: 1.0000 - val_loss: 5.6129 - val_accuracy: 0.7170
# Epoch 68/100
# 100/100 - 57s - loss: 1.5578e-09 - accuracy: 1.0000 - val_loss: 6.0132 - val_accuracy: 0.7170
# Epoch 69/100
# 100/100 - 57s - loss: 5.8736e-10 - accuracy: 1.0000 - val_loss: 6.3604 - val_accuracy: 0.7190
# Epoch 70/100
# 100/100 - 57s - loss: 6.4814e-11 - accuracy: 1.0000 - val_loss: 6.4068 - val_accuracy: 0.7200
# Epoch 71/100
# 100/100 - 57s - loss: 7.4430e-11 - accuracy: 1.0000 - val_loss: 6.3226 - val_accuracy: 0.7200
# Epoch 72/100
# 100/100 - 57s - loss: 4.9256e-11 - accuracy: 1.0000 - val_loss: 6.3814 - val_accuracy: 0.7180
# Epoch 73/100
# 100/100 - 57s - loss: 3.8171e-11 - accuracy: 1.0000 - val_loss: 6.4191 - val_accuracy: 0.7170
# Epoch 74/100
# 100/100 - 57s - loss: 3.3093e-11 - accuracy: 1.0000 - val_loss: 6.4482 - val_accuracy: 0.7150
# Epoch 75/100
# 100/100 - 57s - loss: 3.1287e-11 - accuracy: 1.0000 - val_loss: 6.4713 - val_accuracy: 0.7160
# Epoch 76/100
# 100/100 - 57s - loss: 3.0592e-11 - accuracy: 1.0000 - val_loss: 6.4903 - val_accuracy: 0.7170
# Epoch 77/100
# 100/100 - 57s - loss: 3.0618e-11 - accuracy: 1.0000 - val_loss: 6.5065 - val_accuracy: 0.7180
# Epoch 78/100
# 100/100 - 57s - loss: 3.0871e-11 - accuracy: 1.0000 - val_loss: 6.5209 - val_accuracy: 0.7170
# Epoch 79/100
# 100/100 - 57s - loss: 3.0526e-11 - accuracy: 1.0000 - val_loss: 6.5343 - val_accuracy: 0.7170
# Epoch 80/100
# 100/100 - 57s - loss: 3.1026e-11 - accuracy: 1.0000 - val_loss: 6.5464 - val_accuracy: 0.7170
# Epoch 81/100
# 100/100 - 57s - loss: 3.2687e-11 - accuracy: 1.0000 - val_loss: 6.5574 - val_accuracy: 0.7170
# Epoch 82/100
# 100/100 - 57s - loss: 3.3127e-11 - accuracy: 1.0000 - val_loss: 6.5674 - val_accuracy: 0.7190
# Epoch 83/100
# 100/100 - 57s - loss: 3.4964e-11 - accuracy: 1.0000 - val_loss: 6.5765 - val_accuracy: 0.7200
# Epoch 84/100
# 100/100 - 57s - loss: 3.5218e-11 - accuracy: 1.0000 - val_loss: 6.5850 - val_accuracy: 0.7200
# Epoch 85/100
# 100/100 - 57s - loss: 3.6646e-11 - accuracy: 1.0000 - val_loss: 6.5927 - val_accuracy: 0.7220
# Epoch 86/100
# 100/100 - 57s - loss: 3.8316e-11 - accuracy: 1.0000 - val_loss: 6.6000 - val_accuracy: 0.7220
# Epoch 87/100
# 100/100 - 57s - loss: 3.8489e-11 - accuracy: 1.0000 - val_loss: 6.6070 - val_accuracy: 0.7220
# Epoch 88/100
# 100/100 - 57s - loss: 4.0812e-11 - accuracy: 1.0000 - val_loss: 6.6137 - val_accuracy: 0.7210
# Epoch 89/100
# 100/100 - 56s - loss: 4.2365e-11 - accuracy: 1.0000 - val_loss: 6.6201 - val_accuracy: 0.7220
# Epoch 90/100
# 100/100 - 57s - loss: 4.3711e-11 - accuracy: 1.0000 - val_loss: 6.6262 - val_accuracy: 0.7220
# Epoch 91/100
# 100/100 - 57s - loss: 4.4642e-11 - accuracy: 1.0000 - val_loss: 6.6320 - val_accuracy: 0.7220
# Epoch 92/100
# 100/100 - 57s - loss: 4.6034e-11 - accuracy: 1.0000 - val_loss: 6.6376 - val_accuracy: 0.7220
# Epoch 93/100
# 100/100 - 57s - loss: 4.7681e-11 - accuracy: 1.0000 - val_loss: 6.6430 - val_accuracy: 0.7230
# Epoch 94/100
# 100/100 - 57s - loss: 4.9854e-11 - accuracy: 1.0000 - val_loss: 6.6481 - val_accuracy: 0.7230
# Epoch 95/100
# 100/100 - 57s - loss: 5.0696e-11 - accuracy: 1.0000 - val_loss: 6.5064 - val_accuracy: 0.7180
# Epoch 96/100
# 100/100 - 57s - loss: 4.7922e-11 - accuracy: 1.0000 - val_loss: 6.5278 - val_accuracy: 0.7180
# Epoch 97/100
# 100/100 - 57s - loss: 4.2230e-11 - accuracy: 1.0000 - val_loss: 6.5457 - val_accuracy: 0.7180
# Epoch 98/100
# 100/100 - 57s - loss: 3.9319e-11 - accuracy: 1.0000 - val_loss: 6.5608 - val_accuracy: 0.7180
# Epoch 99/100
# 100/100 - 57s - loss: 3.6946e-11 - accuracy: 1.0000 - val_loss: 6.5737 - val_accuracy: 0.7180
# Epoch 100/100
# 100/100 - 56s - loss: 3.5587e-11 - accuracy: 1.0000 - val_loss: 6.5851 - val_accuracy: 0.7180

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'go', label='Training Loss')
plt.plot(epochs, val_loss, 'g', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image

uploaded=files.upload()

for fn in uploaded.keys():

  path='/content/' + fn
  img=image.load_img(path, target_size=(150, 150))

  x=image.img_to_array(img)
  x=np.expand_dims(x, axis=0)
  images = np.vstack([x])

  classes = model.predict(images, batch_size=10)

  print(classes[0])

  if classes[0]>0:
    print(fn + " is a dog")
  else:
    print(fn + " is a cat")
# Out:
#      <input type="file" id="files-4a145f27-942f-472f-a78f-b24acc5d9685" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a145f27-942f-472f-a78f-b24acc5d9685">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving classifying_the_cats_and_dogs_09.png to classifying_the_cats_and_dogs_09.png
# [1.]
# classifying_the_cats_and_dogs_09.png is a dog
